# %% [markdown]
# # Quiz 1:
# Merge Intervals - Coding Challenge
# Problem Description
# Given an array of intervals where intervals[i] = [start_i, end_i], merge all overlapping intervals and return an array of non-overlapping intervals.
#
# Examples
# Example 1:
# Input: [[1,3], [2,6], [8,10], [15,18]]
# Output: [[1,6], [8,10], [15,18]]
# Example 2:
# Input: [[1,4], [4,5]]
# Output: [[1,5]]
# Example 3:
# Input: [[1,4], [0,2], [3,5]]
# Output: [[0,5]]
#
# Constraints
# ●	1 <= intervals.length <= 10^4
# ●	0 <= start_i <= end_i <= 10^4
#
# Test Cases
# from typing import List
#
# assert merge([[1,3],[2,6],[8,10],[15,18]]) == [[1,6],[8,10],[15,18]]
# assert merge([[1,4],[4,5]]) == [[1,5]]
# assert merge([[1,4],[0,4]]) == [[0,4]]
# Expected: O(n log n) time, O(n) space

# %%
from typing import List

def merge(intervals: List[List[int]]) -> List[List[int]]:
    """
    Merges all overlapping intervals.
    
    Args:
        intervals: List of intervals [start, end]
    Returns:
        List of merged non-overlapping intervals
    """
    intervals = sorted(intervals)
    n = len(intervals)

    ans = []
    ans.append(intervals[0])
    i, j = 0, 1
    while j < n:
        if intervals[j][0] <= ans[i][1]:
            ans[i] = [ans[i][0], intervals[j][1]]
        else:
            ans.append(intervals[j])
            i += 1
        
        j += 1
    
    return ans

print(merge([[1,3],[2,6],[8,10],[15,18]]) == [[1,6],[8,10],[15,18]])
print(merge([[1,4],[4,5]]) == [[1,5]])
print(merge([[1,4],[0,4]]) == [[0,4]])
# Out:
# True
# True
# True

# %%
assert merge([[1,3],[2,6],[8,10],[15,18]]) == [[1,6],[8,10],[15,18]], 'wrong'   
assert merge([[1,4],[4,5]]) == [[1,5]], 'wrong'    
assert merge([[1,4],[0,4]]) == [[0,4]], 'wrong'

# %% [markdown]
# # Quiz 2

# %%
# !python quiz2_OOP_ecommerce_shopping_cart.py
# Out:
#                🛒 SHOPPING CART SYSTEM TESTS 🛒
#
# ...
# TEST 1: Basic Cart Operations
# ...
#
# Adding 2 T-Shirt to cart...
# Cart length: 1
#
# Adding 1 Jeans to cart...
# Cart length: 2
#
# Adding 5 Apple to cart...
# Cart length: 3
#
# Current cart items:
#   - T-Shirt: 2 x $25 = $50
#   - Jeans: 1 x $60 = $60
#   - Apple: 5 x $2 = $10
#
# Total: $120.00
#
# ...
# TEST 2: Stock Validation
# ...
#
# Jacket has 3 items in stock
#
# Attempting to add 5 Jacket (more than stock)...
# ❌ Error caught: Insufficient stock for Jacket. Requested: 5, Available: 3
#
# Adding 2 Jacket (within stock)...
# ✓ Success! Cart has 1 items
#
# Attempting to add 2 more Jacket (total would be 4, exceeds stock of 3)...
# ❌ Error caught: Insufficient stock for Jacket. Requested: 4, Available: 3
#
# Final cart quantity: 1 items
#
# ...
# TEST 3: Remove Item
# ...
#
# Cart has 2 items
# Items:
#   - Banana: 10
#   - Orange: 5
#
# Removing Banana...
# Remove successful: True
# Cart now has 1 items
#
# Trying to remove Banana again...
# ...
